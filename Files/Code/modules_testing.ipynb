# %%
from Modules.load_db import get_dataframe_dict
from Modules.load_db_cleaning import join_datasets

# %%
datasets_dict = get_dataframe_dict([
    'ae-110k',
    'oa-mine',
    'mave',
])
# 10.8s | 6.8s | 7.5s | 25s | 17.4s
# Out:
# Loading dataframe: ae-110k
# Loading dataframes from local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\ae-110k
# Getting specific columns to remove for dataset: ae-110k
# Removing specific columns for dataset: ae-110k
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (39505, 13) to (39505, 4)
# Splitting dataframe into train, validation and test sets with proportions: {'test': 0.1, 'validation': 0.1, 'train': 0.8}
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (3950, 4), 'validation': (3950, 4), 'train': (31605, 4)}
# Loading dataframe: oa-mine
# Loading dataframes from local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\oa-mine
# Getting specific columns to remove for dataset: oa-mine
# Removing specific columns for dataset: oa-mine
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (1943, 11) to (1943, 4)
# Splitting dataframe into train, validation and test sets with proportions: {'test': 0.1, 'validation': 0.1, 'train': 0.8}
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (194, 4), 'validation': (194, 4), 'train': (1555, 4)}
# Loading dataframe: mave
# Loading dataframes from local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\mave
# Getting specific columns to remove for dataset: mave
# Removing specific columns for dataset: mave
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (2675839, 12) to (2675839, 4)
# Splitting dataframe into train, validation and test sets with proportions: {'test': 0.1, 'validation': 0.1, 'train': 0.8}
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (267583, 4), 'validation': (267583, 4), 'train': (2140673, 4)}

# %%
JSONLLM = join_datasets(datasets_dict)
# Out:
# All unique columns across datasets:
# ['dataset', 'json_answer', 'split', 'text']
# Keeping only rows with larger json_answer for each text
