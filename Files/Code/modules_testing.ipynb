# %%
from Modules.load_db import get_dataframes

datasets_dict = {
    'ae-110k': get_dataframes('ae-110k'),
    'oa-mine': get_dataframes('oa-mine'),
    'mave': get_dataframes('mave'),
}
# Out:
# Loading dataframe: ae-110k
# Loading dataframes from Hugging Face for dataset: ae-110k
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (39505, 11) to (39489, 2)
# Splitting dataframe into train, validation and test sets with proportions: {'train': 0.8, 'validation': 0.1, 'test': 0.1}
# Saving dataframes to local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\ae-110k
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (3948, 2), 'validation': (3948, 2), 'train': (31593, 2)}
# Loading dataframe: oa-mine
# Loading dataframes from Hugging Face for dataset: oa-mine
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (1943, 9) to (1938, 2)
# Splitting dataframe into train, validation and test sets with proportions: {'train': 0.8, 'validation': 0.1, 'test': 0.1}
# Saving dataframes to local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\oa-mine
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (193, 2), 'validation': (193, 2), 'train': (1552, 2)}
# Loading dataframe: mave
# Loading dataframes from Hugging Face for dataset: mave
# General Clean: drop_na, keep bigger json_answer, re-index
# Shape Change: from (2675839, 10) to (2073115, 2)
# Splitting dataframe into train, validation and test sets with proportions: {'train': 0.8, 'validation': 0.1, 'test': 0.1}
# Saving dataframes to local path: b:\GitHub\UFMG\JSONLLM\Files\Code\Datasets\mave
# Loaded dataframes with splits: ['test', 'validation', 'train']
# The shapes of the dataframes are: {'test': (207311, 2), 'validation': (207311, 2), 'train': (1658493, 2)}
